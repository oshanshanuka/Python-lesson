# %%
# get request example using requests library

import requests

response = requests.get('https://api.github.com/events')
print(response) 
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %%
import requests 

response = requests.get('https://api.github.com/events')
if response.status_code == 200:
    print("success!.")
    print(response.url)
    print(response.headers)
    print(type(response.headers))
    print(response.headers['Content-Type'])
    print(response.text)
    print(type(response.text))
else:
    print("failes", response.status_code)
# Out:
# success!.
# https://api.github.com/events
# ...

# %%
# json convert to dictionary

data = response.json()
print(data)
print(type(data))
# Out:
# [{'id': '52423879640', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 931047839, 'name': 'chenqikkl/weread2notion-pro', 'url': 'https://api.github.com/repos/chenqikkl/weread2notion-pro'}, 'payload': {'repository_id': 931047839, 'push_id': 25665729728, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '4342d6133555c746dcdd029d17788b22853ba7b2', 'before': 'e490921cf1b27ea2a5495c00bd019b3403448628', 'commits': [{'sha': '4342d6133555c746dcdd029d17788b22853ba7b2', 'author': {'email': 'action@github.com', 'name': 'GitHub Action'}, 'message': 'add new heatmap', 'distinct': True, 'url': 'https://api.github.com/repos/chenqikkl/weread2notion-pro/commits/4342d6133555c746dcdd029d17788b22853ba7b2'}]}, 'public': True, 'created_at': '2025-07-23T03:57:18Z'}, {'
# ...

# %%
# Q1)

import requests

response = requests.get('https://api.github.com/events')
if response.status_code == 200:
    print("success!.")
    if 'application/json' in response.headers.get('Content-Type',''):
        data = response.json()
        print(data) 
    print(response.text)
else:
    print("error while fetching", response.status_code)
# Out:
# success!.
# ...

# %%
# post request example using requests library

import requests

url ='https://httpbin.org/post'
data = {'username':'user', 'password':'pass'}
response = requests.post(url, data=data)

if response.status_code == 200:
    print("Login success!.")
    print(response.text)
    print(response.url)
else:
    print("Login failed", response.status_code)
# Out:
# Login success!.
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "pass",
#     "username": "user"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "27",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68806a36-5aab09e015097bda1759ee35"
#   },
#   "json": null,
#   "origin": "43.252.15.106",
#   "url": "https://httpbin.org/post"
# }
#
# https://httpbin.org/post

# %%
# URL Parameters

import requests

url = 'https://jsonplaceholder.typicode.com/posts'

# parameters youn want to send in the URL
params = {
    'userId': 1,
    'id': 2
}
# Making the request with parameters
response = requests.get(url, params=params)
print(response.url)
print(response.text)
# Out:
# https://jsonplaceholder.typicode.com/posts?userId=1&id=2
# [
#   {
#     "userId": 1,
#     "id": 2,
#     "title": "qui est esse",
#     "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#   }
# ]

# %%
# Basic Authentication

import requests

url = 'https://httpbin.org/get'

# Credentials(username and password)
username = 'user'
password = 'pass'

# sending the get request with basic authentication
response = requests.get(url, auth=(username, password))
if response.status_code == 200:
    print("Authentication success!.")
    print(response.text)
else:
    print("Authentication failed", response.status_code)
# Out:
# Authentication success!.
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic dXNlcjpwYXNz",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-688070c6-662340ff010375cb4d7ae217"
#   },
#   "origin": "43.252.15.106",
#   "url": "https://httpbin.org/get"
# }

# %%
# Beatiful Soup Example

from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie&quot; class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie&quot; class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie&quot; class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.title)

print(soup.p) #plweni p tag ek print wei

print(soup.a) # plweni a tag ek print wei 

p_tag = soup.find('p')
print(p_tag)  # prints the first <p> tag found

p_tags = soup.find_all('p')
print(p_tags)  # prints all <p> tags found (list ekk wdyt return wei)
# Out:
# <title>The Dormouse's story</title>
# <p class="title"><b>The Dormouse's story</b></p>
# <a href='http://example.com/elsie" class=' id="link1" sister"="">Elsie</a>
# <p class="title"><b>The Dormouse's story</b></p>
# [<p class="title"><b>The Dormouse's story</b></p>, <p class="story">Once upon a time there were three little sisters; and their names were
# <a href='http://example.com/elsie" class=' id="link1" sister"="">Elsie</a>,
# <a href='http://example.com/lacie" class=' id="link2" sister"="">Lacie</a> and
# <a href='http://example.com/tillie" class=' id="link3" sister"="">Tillie</a>;
# and they lived at the bottom of a well.</p>, <p class="story">...</p>]

# %%
import requests

response = requests.get('https://example.com')
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    main_headline = soup.find('h1')
    if main_headline:
        print("main heading:", main_headline.get_text())
    else:
        print("No main heading found")
else:
    print("Failed", response.status_code)
# Out:
# main heading: Example Domain

# %%
# API Integration Example

import requests

url = "https://api.open-meteo.com/v1/forecast?"

latitude, longitude = 52.52, 13.41
current_info = "temperature_2m,humidity_2m,wind_speed_10m"

params = {
    'latitude': latitude,
    'longitude': longitude,
    'current_info': current_info,
}

response = requests.get(url, params=params)
if response.status_code == 200:
    weather_data = response.json()
    print("Weather data:", weather_data)
else:
    print("Failed to retrieve weather data", response.status_code)
# Out:
# Weather data: {'latitude': 52.52, 'longitude': 13.419998, 'generationtime_ms': 0.0010728836059570312, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 38.0}

# %%
def fetch_weather(latitude, longitude,current_info):
    url = "https://api.open-meteo.com/v1/forecast?"

    params = {
        'latitude': latitude,
        'longitude': longitude,
        'current_info': current_info,
    }

    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to retrieve weather data", response.status_code)
        return None

weather_data = fetch_weather(52.52, 13.41, "temperature_2m,wind_speed_10m")
print("Weather data:", weather_data)
# Out:
# Weather data: {'latitude': 52.52, 'longitude': 13.419998, 'generationtime_ms': 0.00095367431640625, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 38.0}

# %%
def parsing_weather_data(weather_data):
    if weather_data and 'current_weather' not in weather_data:
        print("No current weather data available.")
        return None
    current_weather = weather_data['current_weather']
    wind_speed = current_weather.get('wind_speed_10m', 'N/A')
    return{
        'wind_speed': wind_speed,
        'temperature': current_weather.get('temperature_2m', 'N/A'),
    }
weather_data = fetch_weather(52.52, 13.41, "temperature_2m,wind_speed_10m")
parsed_data = parsing_weather_data(weather_data)
print(parsed_data)
# Out:
# No current weather data available.
# None
